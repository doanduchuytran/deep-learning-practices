# %% [markdown]
# # Multiclass classification from scratch

# %% [markdown]
# ## Imports

# %%
import sys
import os

# Add the parent directory to Python path
sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
import matplotlib.pyplot as plt

from framework.layers import Linear
from framework.activations import ReLU, Softmax
from framework.losses import CrossEntropy
from framework.model import NeuralNetwork
from framework.optimizer import SGD
from framework.trainer import Trainer
from framework.metrics import accuracy

from datasets.mnist_dataset import MNISTDataset

# %% [markdown]
# ## Load Dataset

# %%
dataset = MNISTDataset()

X_train, X_test, y_train, y_test = dataset.load()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 dataset = MNISTDataset()
# ----> 3 X_train, X_test, y_train, y_test = dataset.load()
#
# File ~/sources/SI5101701-Deep-Learning/week_2_assignment/datasets/mnist_dataset.py:14, in MNISTDataset.load(self)
#      10 X, y = fetch_openml("mnist_784", version=1, return_X_y=True)
#      12 X = X / 255.0
# ---> 14 encoder = OneHotEncoder(sparse=False)
#      16 y = encoder.fit_transform(y.values.reshape(-1,1))
#      18 return train_test_split(
#      19     X,
#      20     y,
#      21     test_size=0.2,
#      22     random_state=42
#      23 )
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %% [markdown]
# ## Build Model

# %%
model = NeuralNetwork()

model.add(Linear(784,128))
model.add(ReLU())

model.add(Linear(128,64))
model.add(ReLU())

model.add(Linear(64,10))
model.add(Softmax())

# %% [markdown]
# ## Training

# %%
loss = CrossEntropy()

optimizer = SGD(lr=0.01)

trainer = Trainer(model,loss,optimizer)

losses = trainer.train(X_train,y_train,epochs=20)

# %% [markdown]
# ## Evaluate

# %%
y_pred = model.forward(X_test)

acc = accuracy(y_pred, y_test)

print("Test Accuracy:", acc)
