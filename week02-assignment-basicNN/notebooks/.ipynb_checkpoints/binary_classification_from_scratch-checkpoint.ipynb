# %% [markdown]
# # Neural Network Binary Classification (From Scratch)
#
# Goal:
# Classify tumors as benign or malignant.

# %% [markdown]
# ## Imports

# %%
import sys
import os

# Add the parent directory to Python path
sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
import matplotlib.pyplot as plt

from framework.layers import Linear
from framework.activations import ReLU, Sigmoid
from framework.losses import BinaryCrossEntropy
from framework.model import NeuralNetwork
from framework.optimizer import SGD
from framework.trainer import Trainer
from framework.metrics import binary_accuracy

from datasets.cancer_dataset import CancerDataset

# %% [markdown]
# ## Load Data

# %%
dataset = CancerDataset()

X_train, X_test, y_train, y_test = dataset.load()

# %% [markdown]
# ## Build Model

# %%
model = NeuralNetwork()

model.add(Linear(30,32))
model.add(ReLU())

model.add(Linear(32,16))
model.add(ReLU())

model.add(Linear(16,1))
model.add(Sigmoid())

# %% [markdown]
# ## Training

# %%
loss = BinaryCrossEntropy()

optimizer = SGD(lr=0.01)

trainer = Trainer(model, loss, optimizer)

losses = trainer.train(X_train,y_train,epochs=30)
# Out:
# Epoch 0 Loss 0.6931
# Epoch 1 Loss 0.6931
# Epoch 2 Loss 0.6931
# Epoch 3 Loss 0.6930
# Epoch 4 Loss 0.6930
# Epoch 5 Loss 0.6929
# Epoch 6 Loss 0.6929
# Epoch 7 Loss 0.6929
# Epoch 8 Loss 0.6928
# Epoch 9 Loss 0.6928
# Epoch 10 Loss 0.6927
# Epoch 11 Loss 0.6927
# Epoch 12 Loss 0.6926
# Epoch 13 Loss 0.6926
# Epoch 14 Loss 0.6926
# Epoch 15 Loss 0.6925
# Epoch 16 Loss 0.6925
# Epoch 17 Loss 0.6924
# Epoch 18 Loss 0.6924
# Epoch 19 Loss 0.6924
# Epoch 20 Loss 0.6923
# Epoch 21 Loss 0.6923
# Epoch 22 Loss 0.6922
# Epoch 23 Loss 0.6922
# Epoch 24 Loss 0.6922
# Epoch 25 Loss 0.6921
# Epoch 26 Loss 0.6921
# Epoch 27 Loss 0.6920
# Epoch 28 Loss 0.6920
# Epoch 29 Loss 0.6920

# %% [markdown]
# ## Plot Loss

# %%
plt.plot(losses)

plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Evaluate Accuracy

# %%
y_pred = model.forward(X_test)

acc = binary_accuracy(y_pred, y_test)

print("Test Accuracy:", acc)
# Out:
# Test Accuracy: 0.6228070175438597
